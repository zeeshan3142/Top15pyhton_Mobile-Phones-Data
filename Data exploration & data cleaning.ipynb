# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings ("ignore")

# %%
zk=pd.read_csv("C:/Users/ZEESHAN KHAN/OneDrive/Documents/Downloads/Levels_Fyi_Salary_Data.csv")

# %% [markdown]
# ## LETS EXPLORE THE DATA

# %%
zk.shape #To check the shape of the data
# Out:
# (62642, 29)

# %%
zk1=zk['company']=='Google'  # filtering only google company information from this data set

# %%
zk[zk1]
# Out:
#                  timestamp company level              title  \
# 28        08-07-2017 02:08  Google    L4  Software Engineer
# 29        08-07-2017 11:19  Google    T6  Software Engineer
# 86     10/25/2017 10:30:54  Google    L4  Software Engineer
# 94     11/14/2017 20:39:43  Google    T3  Software Engineer
# 96     11/16/2017 18:40:36  Google    L4  Software Engineer
# ...                    ...     ...   ...                ...
# 62604     08-01-2018 01:25  Google    L3  Software Engineer
# 62606     08-01-2018 19:35  Google    T3  Software Engineer
# 62621   8/15/2018 20:18:36  Google    L4  Software Engineer
# 62627   8/23/2018 14:04:45  Google    T3  Software Engineer
# 62637     09-09-2018 11:52  Google    T4  Software Engineer
#
#        totalyearlycompensation           location  yearsofexperience  \
# 28                    300000.0  Mountain View, CA                8.0
# 29                    440000.0       New York, NY               14.0
# ...

# %%
zk2=zk[zk1] # Alligning all google information in zk2

# %%
zk2
# Out:
#                  timestamp company level              title  \
# 28        08-07-2017 02:08  Google    L4  Software Engineer
# 29        08-07-2017 11:19  Google    T6  Software Engineer
# 86     10/25/2017 10:30:54  Google    L4  Software Engineer
# 94     11/14/2017 20:39:43  Google    T3  Software Engineer
# 96     11/16/2017 18:40:36  Google    L4  Software Engineer
# ...                    ...     ...   ...                ...
# 62604     08-01-2018 01:25  Google    L3  Software Engineer
# 62606     08-01-2018 19:35  Google    T3  Software Engineer
# 62621   8/15/2018 20:18:36  Google    L4  Software Engineer
# 62627   8/23/2018 14:04:45  Google    T3  Software Engineer
# 62637     09-09-2018 11:52  Google    T4  Software Engineer
#
#        totalyearlycompensation           location  yearsofexperience  \
# 28                    300000.0  Mountain View, CA                8.0
# 29                    440000.0       New York, NY               14.0
# ...

# %%
zk2.sort_values(['level'],ascending=[True]).head(10) # sorting a level coloumn in a ascending order
# Out:
#                  timestamp company level              title  \
# 38084  12/24/2020 20:22:01  Google     2          Marketing
# 33732  10/25/2020 18:22:35  Google     2  Software Engineer
# 48582   4/16/2021 16:42:08  Google     3  Software Engineer
# 10524     09-08-2019 20:14  Google     3  Software Engineer
# 4180      02-07-2019 09:52  Google     3  Software Engineer
# 16045     02-03-2020 18:36  Google     3  Hardware Engineer
# 62012   3/23/2018 12:51:20  Google     3  Software Engineer
# 32645  10/13/2020 14:26:51  Google     3          Marketing
# 31286    9/29/2020 1:26:38  Google     3  Software Engineer
# 654     7/30/2018 23:30:37  Google     3  Software Engineer
#
#        totalyearlycompensation           location  yearsofexperience  \
# 38084                 123000.0       New York, NY                2.0
# 33732                 225000.0      San Diego, CA                2.0
# 48582                 210000.0  Mountain View, CA                5.0
# ...

# %%
zk3=zk2['location']=='New York, NY'
zk2[zk3]  # showing only NY location data
# Out:
#                 timestamp company level              title  \
# 29       08-07-2017 11:19  Google    T6  Software Engineer
# 117      01-02-2018 23:26  Google    T2  Software Engineer
# 139     1/24/2018 4:51:35  Google    T7  Software Engineer
# 174     2/15/2018 9:12:47  Google    L3  Software Engineer
# 291    4/24/2018 20:05:01  Google    L3  Software Engineer
# ...                   ...     ...   ...                ...
# 62227    11-01-2018 08:00  Google    L3  Software Engineer
# 62273    01-04-2018 09:56  Google    L4  Software Engineer
# 62326    11-07-2017 22:38  Google    T5  Software Engineer
# 62366    02-04-2018 13:05  Google    T3  Software Engineer
# 62575  7/13/2018 10:25:20  Google    L3  Software Engineer
#
#        totalyearlycompensation      location  yearsofexperience  \
# 29                    440000.0  New York, NY               14.0
# 117                   110000.0  New York, NY                0.0
# ...

# %%
zk2[zk3]['basesalary'].max() #check the maximun salary of new york location
# Out:
# 278000.0

# %% [markdown]
# ## Lets cleaning the data

# %%
zk.columns #Checking the columns name
# Out:
# Index(['timestamp', 'company', 'level', 'title', 'totalyearlycompensation',
#        'location', 'yearsofexperience', 'yearsatcompany', 'tag', 'basesalary',
#        'stockgrantvalue', 'bonus', 'gender', 'otherdetails', 'cityid', 'dmaid',
#        'rowNumber', 'Masters_Degree', 'Bachelors_Degree', 'Doctorate_Degree',
#        'Highschool', 'Some_College', 'Race_Asian', 'Race_White',
#        'Race_Two_Or_More', 'Race_Black', 'Race_Hispanic', 'Race', 'Education'],
#       dtype='object')

# %%
zk= zk.drop(['rowNumber','Race','Race_Hispanic','Race_Hispanic','Race_Black','Race_Two_Or_More','Race_White','Race_Asian',], axis=1)

#Removing the columns which is not required

# %%
zk.columns # After removing the columns checking the columns
# Out:
# Index(['timestamp', 'company', 'level', 'title', 'totalyearlycompensation',
#        'location', 'yearsofexperience', 'yearsatcompany', 'tag', 'basesalary',
#        'stockgrantvalue', 'bonus', 'gender', 'otherdetails', 'cityid', 'dmaid',
#        'Masters_Degree', 'Bachelors_Degree', 'Doctorate_Degree', 'Highschool',
#        'Some_College', 'Education'],
#       dtype='object')

# %%
zk.isnull().sum() #CHECKING NULL VALUES
# Out:
# timestamp                      0
# company                        5
# level                        119
# title                          2
# totalyearlycompensation        2
# location                      38
# yearsofexperience              0
# yearsatcompany                 0
# tag                          854
# basesalary                     5
# stockgrantvalue                0
# bonus                          0
# gender                     19540
# otherdetails               22505
# cityid                         0
# dmaid                          2
# Masters_Degree                 0
# Bachelors_Degree               0
# Doctorate_Degree               0
# Highschool                     0
# Some_College                   0
# Education                  32272
# dtype: int64

# %%
zk= zk.drop(['gender','otherdetails','Education',], axis=1)

#Removing this columns because this data having null value more than 50%

# %%
zk.isnull().sum()
# Out:
# timestamp                    0
# company                      5
# level                      119
# title                        2
# totalyearlycompensation      2
# location                    38
# yearsofexperience            0
# yearsatcompany               0
# tag                        854
# basesalary                   5
# stockgrantvalue              0
# bonus                        0
# cityid                       0
# dmaid                        2
# Masters_Degree               0
# Bachelors_Degree             0
# Doctorate_Degree             0
# Highschool                   0
# Some_College                 0
# dtype: int64

# %%
zk.info() # checking tha data types for each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62642 entries, 0 to 62641
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                62642 non-null  object
#  1   company                  62637 non-null  object
#  2   level                    62523 non-null  object
#  3   title                    62640 non-null  object
#  4   totalyearlycompensation  62640 non-null  float64
#  5   location                 62604 non-null  object
#  6   yearsofexperience        62642 non-null  float64
#  7   yearsatcompany           62642 non-null  float64
#  8   tag                      61788 non-null  object
#  9   basesalary               62637 non-null  float64
#  10  stockgrantvalue          62642 non-null  float64
#  11  bonus                    62642 non-null  float64
#  12  cityid                   62642 non-null  int64
#  13  dmaid                    62640 non-null  float64
# ...

# %%
sns.boxplot(zk.basesalary)   #Checking the Distributio of Data with boxplot for "basesalary" column
# Out:
# <AxesSubplot:xlabel='basesalary'>

# %%
sns.distplot(zk.basesalary) #checking the distribution
# Out:
# <AxesSubplot:xlabel='basesalary', ylabel='Density'>

# %%
zk['basesalary'] = zk['basesalary'].fillna(zk['basesalary'].median())

# %%
zk.isnull().sum()
# Out:
# timestamp                    0
# company                      5
# level                      119
# title                        2
# totalyearlycompensation      2
# location                    38
# yearsofexperience            0
# yearsatcompany               0
# tag                        854
# basesalary                   0
# stockgrantvalue              0
# bonus                        0
# cityid                       0
# dmaid                        2
# Masters_Degree               0
# Bachelors_Degree             0
# Doctorate_Degree             0
# Highschool                   0
# Some_College                 0
# dtype: int64
